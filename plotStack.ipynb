# %%
import pyleoclim as pyleo
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("./raw_data/cleantg01c.csv") 
df2 = pd.read_csv("./raw_data/cleantg11a.csv")
df3 = pd.read_csv("./raw_data/cleanmun63.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0     date    c13    o18
# 0           0  1712.08 -24.23  27.37
# 1           1  1712.25 -24.20  27.40
# 2           2  1712.42 -25.05  26.69
# 3           3  1712.58 -24.40  26.52
# 4           4  1712.75 -25.04  26.36

# %%
tg01c = pyleo.Series(time =  df1['date'], value = df1["o18"],
                  time_name = 'Year', value_name = '$\delta^{18}$O of tg01c',
                  time_unit = 'CE', value_unit = '‰, VSMOW')

tg11a = pyleo.Series(time =  df2['date'], value = df2["o18"],
                  time_name = 'Year', value_name = '$\delta^{18}$O of tg11a',
                  time_unit = 'CE', value_unit = '‰, VSMOW')

mun63 = pyleo.Series(time =  df3['date'], value = df3["o18"],
                  time_name = 'Year', value_name = '$\delta^{18}$O of mun63',
                  time_unit = 'CE', value_unit = '‰, VSMOW')

# %%
mun = pyleo.MultipleSeries([tg01c, tg11a, mun63], name="Muna $\delta^{18}O_c$ time series")

# %%
mun.stackplot()
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  {0: <matplotlib.axes._axes.Axes at 0x7ff304b431c0>,
#   1: <matplotlib.axes._axes.Axes at 0x7ff304b6aaf0>,
#   2: <matplotlib.axes._axes.Axes at 0x7ff304b3fa30>,
#   3: <matplotlib.axes._axes.Axes at 0x7ff304b43160>})
